# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/home/bhavye/Desktop/data/analysis/datasets/country_wise_latest.csv")
df.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
# df['total_cases'] = df['Confirmed'] + df['Active']
df.sort_values(by='Active',ascending=False,inplace=True)
df.reset_index(inplace=True)
df.head()
# Out:
#    index  Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 0    173              US    4290259  148011    1325804  2816444      56336
# 1     23          Brazil    2442375   87618    1846641   508116      23284
# 2     79           India    1480073   33408     951166   495499      44457
# 3    177  United Kingdom     301708   45844       1437   254427        688
# 4    138          Russia     816680   13334     602249   201097       5607
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0        1076          27941                3.45                  30.90
# 1         614          33728                3.59                  75.61
# 2         637          33598                2.26                  64.26
# 3           7              3               15.19                   0.48
# 4          85           3077                1.63                  73.74
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
df.describe()
# Out:
#             index     Confirmed         Deaths     Recovered        Active  \
# count  187.000000  1.870000e+02     187.000000  1.870000e+02  1.870000e+02
# mean    93.000000  8.813094e+04    3497.518717  5.063148e+04  3.400194e+04
# std     54.126395  3.833187e+05   14100.002482  1.901882e+05  2.133262e+05
# min      0.000000  1.000000e+01       0.000000  0.000000e+00  0.000000e+00
# 25%     46.500000  1.114000e+03      18.500000  6.265000e+02  1.415000e+02
# 50%     93.000000  5.059000e+03     108.000000  2.815000e+03  1.600000e+03
# 75%    139.500000  4.046050e+04     734.000000  2.260600e+04  9.149000e+03
# max    186.000000  4.290259e+06  148011.000000  1.846641e+06  2.816444e+06
#
#           New cases   New deaths  New recovered  Deaths / 100 Cases  \
# count    187.000000   187.000000     187.000000          187.000000
# mean    1222.957219    28.957219     933.812834            3.019519
# std     5710.374790   120.037173    4197.719635            3.454302
# ...

# %%
# df.drop('level_0',axis=1,inplace=True)
# df.describe()
df.drop('index',axis=1,inplace=True)
df.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
df.head()
# Out:
#    Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 0              US    4290259  148011    1325804  2816444      56336
# 1          Brazil    2442375   87618    1846641   508116      23284
# 2           India    1480073   33408     951166   495499      44457
# 3  United Kingdom     301708   45844       1437   254427        688
# 4          Russia     816680   13334     602249   201097       5607
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0        1076          27941                3.45                  30.90
# 1         614          33728                3.59                  75.61
# 2         637          33598                2.26                  64.26
# 3           7              3               15.19                   0.48
# 4          85           3077                1.63                  73.74
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
plt.plot(df.index,df['Active']/df['Confirmed'] * 100)
# plt.scatter(df.index,df['Active']/df['Confirmed'] * 100)

# %%
print(df['WHO Region'].unique())
df.groupby(by='WHO Region').max(numeric_only=True)
# Out:
# ['Americas' 'South-East Asia' 'Europe' 'Africa' 'Western Pacific'
#  'Eastern Mediterranean']
#                        Confirmed  Deaths  Recovered   Active  New cases  \
# WHO Region
# Africa                    452529    7067     274925   170537       7096
# Americas                 4290259  148011    1846641  2816444      56336
# Eastern Mediterranean     293606   15912     255144    52992       2553
# Europe                    816680   45844     602249   254427       5607
# South-East Asia          1480073   33408     951166   495499      44457
# Western Pacific            86783    4656      78869    53649       1592
#
#                        New deaths  New recovered  Deaths / 100 Cases  \
# WHO Region
# Africa                        298           9848               10.00
# Americas                     1076          33728               11.13
# Eastern Mediterranean         212           3592               28.56
# ...

# %%
# print(f"Country having maximum new cases : {df[df['New cases']==df['New cases'].max()]['Country/Region']}")
df[df['New cases']==df['New cases'].max()] # Maximum new cases in US
# Out:
#   Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 0             US    4290259  148011    1325804  2816444      56336
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0        1076          27941                3.45                   30.9
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                   11.16              3834677         455582
#
#    1 week % increase WHO Region
# 0              11.88   Americas

# %%
df[df['New cases']==df['New cases'].min()].head() # Minimum new covid cases i.e 0 new cases
# Out:
#                Country/Region  Confirmed  Deaths  Recovered  Active  \
# 11                      Spain     272421   28432     150376   93613
# 77   Central African Republic       4599      59       1546    2994
# 85          Equatorial Guinea       3071      51        842    2178
# 102             Guinea-Bissau       1954      26        803    1125
# 106                 Nicaragua       3439     108       2492     839
#
#      New cases  New deaths  New recovered  Deaths / 100 Cases  \
# 11           0           0              0               10.44
# 77           0           0              0                1.28
# 85           0           0              0                1.66
# 102          0           0              0                1.33
# 106          0           0              0                3.14
#
#      Recovered / 100 Cases  Deaths / 100 Recovered  Confirmed last week  \
# 11                   55.20                   18.91               264836
# ...

# %%
# df.head()
# sns.displot(data=df,x=df['Deaths / 100 Cases'],kde=True)
# plt.figure(figsize=(10,10))
sns.histplot(data=df,x=df['Deaths / 100 Cases'])
print(df['Deaths / 100 Cases'].value_counts().head())
# Out:
# 0.00    17
# 1.28     3
# 2.91     3
# 0.68     2
# 1.69     2
# Name: Deaths / 100 Cases, dtype: int64

# %%
df.sort_values(by='Deaths / 100 Cases',ascending=False).head()
# Out:
#      Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 124           Yemen       1691     483        833     375         10
# 3    United Kingdom     301708   45844       1437  254427        688
# 21          Belgium      66428    9822      17452   39154        402
# 38            Italy     246286   35112     198593   12581        168
# 7            France     220352   30212      81212  108928       2551
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 124           4             36               28.56                  49.26
# 3             7              3               15.19                   0.48
# 21            1             14               14.79                  26.27
# 38            5            147               14.26                  80.64
# 7            17            267               13.71                  36.86
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
# Active = (confirmed - recovered) - Death
## Top 5 contries with maximum deaths
df.sort_values(by='Deaths',ascending=False).head()
# Out:
#     Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 0               US    4290259  148011    1325804  2816444      56336
# 1           Brazil    2442375   87618    1846641   508116      23284
# 3   United Kingdom     301708   45844       1437   254427        688
# 16          Mexico     395489   44022     303810    47657       4973
# 38           Italy     246286   35112     198593    12581        168
#
#     New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0         1076          27941                3.45                  30.90
# 1          614          33728                3.59                  75.61
# 3            7              3               15.19                   0.48
# 16         342           8588               11.13                  76.82
# 38           5            147               14.26                  80.64
#
#     Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
df.sort_values(by='Recovered',ascending=False).head()
# Out:
#    Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 1          Brazil    2442375   87618    1846641   508116      23284
# 0              US    4290259  148011    1325804  2816444      56336
# 2           India    1480073   33408     951166   495499      44457
# 4          Russia     816680   13334     602249   201097       5607
# 35          Chile     347923    9187     319954    18782       2133
#
#     New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 1          614          33728                3.59                  75.61
# 0         1076          27941                3.45                  30.90
# 2          637          33598                2.26                  64.26
# 4           85           3077                1.63                  73.74
# 35          75           1859                2.64                  91.96
#
#     Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
# df['WHO Region'].value_counts()
df.groupby(by='WHO Region').max()
# Out:
#                       Country/Region  Confirmed  Deaths  Recovered   Active  \
# WHO Region
# Africa                      Zimbabwe     452529    7067     274925   170537
# Americas                   Venezuela    4290259  148011    1846641  2816444
# Eastern Mediterranean          Yemen     293606   15912     255144    52992
# Europe                    Uzbekistan     816680   45844     602249   254427
# South-East Asia          Timor-Leste    1480073   33408     951166   495499
# Western Pacific              Vietnam      86783    4656      78869    53649
#
#                        New cases  New deaths  New recovered  \
# WHO Region
# Africa                      7096         298           9848
# Americas                   56336        1076          33728
# Eastern Mediterranean       2553         212           3592
# Europe                      5607          85           3077
# South-East Asia            44457         637          33598
# ...

# %%
sns.jointplot(data=df,x=df['Confirmed'],y=df['Recovered'])
# As the confirmed cases increases, Recovering Cases also increases for most of test cases

# %%
sns.jointplot(data=df,x=df['Deaths'],y=df['Recovered'])
plt.grid()
